# %% [markdown]
# # Link to the Problem Set 1
#
# https://cs50.harvard.edu/python/2022/psets/1/

# %%
# Deep Thought

def main():
    answer = input("What is your answer to the Great Question of Life? ").strip().lower()

    if is_correct(answer):
        print("Yes")

    else:
        print("No")


def is_correct(answer):

    match answer:

        case "forty two" | "forty-two" | "42":
            return True
        
        case _:
            return False


main()

# %%
# Home Federal Savings Bank

def main():
    greeting = input("Please give your greetigns: ").strip().lower()

    if greeting.startswith("hello"):
        print("$0")

    elif greeting.startswith("h"):
        print("$20")
        
    else:
        print("$100")


main()

# %%
# File Extensions 

def main():
    file_name = input("Please enter your file name: ").strip().lower()

    if file_name.endswith(".gif"):
        print("image/gif")

    elif file_name.endswith(".jpg"):
        print("image/jpeg")

    elif file_name.endswith(".jpeg"):
        print("image/jpeg")

    elif file_name.endswith(".png"):
        print("image/png")

    elif file_name.endswith(".pdf"):
        print("application/pdf")

    elif file_name.endswith(".txt"):
        print("text/plain")

    elif file_name.endswith(".zip"):
        print("application/zip")
        
    else:
        print("application/octet-stream")


main()

# %%
# Math Interpreter

def main():
    expression = input("Please enter you math expression: ").strip()
    expression = expression.split()
    x = int(expression[0])
    y = expression[1]
    z = int(expression[2])

    if y == "+":
        print(float(x + z))

    elif y == "-":
        print(float(x - z))

    elif y == "*":
        print(float(x * z))
        
    elif y == "/":
        print(float(x / z))


main()

# %%
# Meal Time

def main():
    time = input("What is the time? ").strip()
    time = convert(time)

    if 7.0 <= time <= 8.0:
        print("breakfast time")

    elif 12.0 <= time <= 13.0:
        print("lunch time")

    elif 18.0 <= time <= 19.0:
        print("dinner time")


def convert(time):

    if time.endswith(" a.m."):
        time = time.removesuffix(" a.m.")
        hours, minutes = time.split(":")

        if int(hours) == 12:
            hours = str(0)

        minutes = int(minutes) / 60
        time = int(hours) + minutes

    elif time.endswith(" p.m."):
        time = time.removesuffix(" p.m.")
        hours, minutes = time.split(":")

        if 1 <= int(hours) < 12:
            hours = str(int(hours) + 12)

        minutes = int(minutes) / 60
        time = int(hours) + minutes

    else:
        hours, minutes = time.split(":")
        minutes = int(minutes) / 60
        time = int(hours) + minutes

    return time


if __name__ == "__main__":
    main()
